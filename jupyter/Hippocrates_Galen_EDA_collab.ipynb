# %% [markdown]
# # Ancient Medical Authors: Exploratory Data Analysis

# %% [markdown]
# ## Step 1: Clone the Github repo and install libraries

# %%
# clone repo and install libraries
# !git clone https://github.com/mgbilby/oga_src.git
# !pip install conllu pandas

# import libraries
import os
import pandas as pd
from conllu import parse_incr
from collections import defaultdict
from textwrap import dedent

# %% [markdown]
# ## Step 2: Define the data directory, select authors by cts_urn prefix, and check inputs

# %%
authors = {
    "Hippocrates": [f for f in os.listdir(data_dir) if f.startswith("tlg0627") and f.endswith(".conllu")],
    "Galen": [f for f in os.listdir(data_dir) if f.startswith("tlg0057") and f.endswith(".conllu")]
}

# Check loaded files
for author, files in authors.items():
    if not files:
        print(f"Warning: No files found for {author}.")
    else:
        print(f"Found {len(files)} files for {author}:")
        print("\n".join(files))
# Out:
# Found 52 files for Hippocrates:
# tlg0627.tlg016.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg047.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg042.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg033.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg037.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg051.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg032.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg008.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg048.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg046.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg030.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg018.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg049.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg036.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg021.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg025.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg053.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg003.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg019.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg043.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg013.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg012.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg026.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg024.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg045.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg050.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg040.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg005.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg009.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg038.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg002.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg007.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg041.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg017.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg014.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg035.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg022.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg001.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg055.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg039.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg029.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg006.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg028.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg004.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg011.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg023.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg010.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg031.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg015.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg027.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg052.1st1K-grc1_oga020_src.conllu
# tlg0627.tlg020.1st1K-grc1_oga020_src.conllu
# Found 97 files for Galen:
# tlg0057.tlg107.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg054.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg055.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg021.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg018.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg093.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg060.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg019.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg003.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg027.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg059.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg096.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg009.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg050.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg073.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg103.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg062.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg065.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg067.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg064.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg066.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg099.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg015.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg042.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg085.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg011.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg024.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg057.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg072.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg047.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg013.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg071.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg048.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg002.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg001.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg025.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg087.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg017.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg086.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg083.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg063.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg061.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg089.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg031.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg006.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg046.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg045.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg102.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg028.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg101.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg074.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg035.1st1K-grc2_oga020_src.conllu
# tlg0057.tlg058.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg100.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg095.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg070.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg052.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg036.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg043.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg039.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg051.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg068.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg022.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg007.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg029.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg012.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg030.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg084.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg020.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg056.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg075.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg053.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg008.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg041.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg069.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg092.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg081.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg094.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg049.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg077.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg037.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg044.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg034.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg032.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg082.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg023.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg033.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg010.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg079.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg014.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg076.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg040.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg114.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg038.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg078.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg004.1st1K-grc1_oga020_src.conllu
# tlg0057.tlg016.1st1K-grc1_oga020_src.conllu

# %% [markdown]
# ## Step 3: Create functions to extract work title, parse CoNNL-U files, and convert to df

# %%
# Define the function to extract the work title
def extract_work_title(filepath):
    """
    Extracts the work title from the MISC column in the first token of the file.
    """
    with open(filepath, "r", encoding="utf-8") as file:
        for line in file:
            if line.startswith("1\t"):  # First token line
                columns = line.strip().split("\t")
                if len(columns) > 9 and "ref=" in columns[9]:
                    ref_field = columns[9]
                    # Extract the title after 'ref=' and before the first underscore
                    title_start = ref_field.find("ref=") + 4
                    title_end = ref_field.find("_", title_start)
                    return ref_field[title_start:title_end]
    return "Unknown Work"

# Define the function to parse CoNLL-U files
def parse_conllu_file(filepath, work_title):
    """
    Parses a CoNLL-U file and converts it to a pandas DataFrame, including sentence IDs.
    """
    with open(filepath, "r", encoding="utf-8") as file:
        sentences = parse_incr(file)
        rows = []
        word_count = 0
        for sentence in sentences:
            # Extract the sentence ID (sent_id) and sentence text (# text)
            sent_id = sentence.metadata.get("sent_id", "Unknown")
            sentence_text = sentence.metadata.get("text", "")

            for token in sentence:
                rows.append({
                    "form": token["form"],  # Surface form
                    "lemma": token.get("lemma", "_"),  # Lemma
                    "upostag": token.get("upostag", "_"),  # Universal POS tag
                    "xpostag": token.get("xpostag", "_"),  # Language-specific POS tag
                    "feats": token.get("feats", "_"),  # Morphological features
                    "deprel": token.get("deprel", "_"),  # Syntactic relation
                    "work_title": work_title,  # Add the extracted work title
                    "sent_id": sent_id,  # Include the sentence ID
                    "sentence_text": sentence_text,  # Include the full sentence text
                })
                word_count += 1
    return pd.DataFrame(rows), word_count

# %% [markdown]
# ## Step 4: Load and parse files for selected authors into a dataframe

# %%
# Load and parse all files for both authors
data = {}
word_counts_by_author = defaultdict(int)  # To store total word counts for each author

for author, files in authors.items():
    author_data = []
    print(f"Processing works by {author}...")
    for file in files:
        filepath = os.path.join(data_dir, file)
        print(f"  Parsing {file}...")

        # Extract the work title
        work_title = extract_work_title(filepath)
        if work_title:
            print(f"    Work title identified: {work_title}")
        else:
            print(f"    Work title could not be identified for {file}. Skipping...")
            continue

        # Parse the file into a DataFrame and calculate word count
        df, word_count = parse_conllu_file(filepath, work_title)
        print(f"    Word token count is {word_count}")

        if not df.empty:
            df["source_file"] = file  # Add a column to indicate the source file
            df["author"] = author  # Add a column to indicate the author
            author_data.append(df)
            word_counts_by_author[author] += word_count  # Update total word count for the author

    if author_data:
        data[author] = pd.concat(author_data, ignore_index=True)

# Combine data into a single DataFrame for easy querying
if data:
    combined_df = pd.concat(data.values(), ignore_index=True)
    print("Data successfully parsed and combined.")
else:
    print("No data parsed. Please check your files and code.")

# Output total word token count for each author
print("\nTotal word token counts by author:")
for author, total_count in word_counts_by_author.items():
    print(f"  {author}: {total_count} tokens")

# Sample output of combined data
print("\nSample of the parsed data:")
print(combined_df.head())
# Out:
# Processing works by Hippocrates...
#   Parsing tlg0627.tlg016.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Prorrheticon I
#     Word token count is 12993
#   Parsing tlg0627.tlg047.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De visu
#     Word token count is 995
#   Parsing tlg0627.tlg042.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De glandulis
#     Word token count is 2180
#   Parsing tlg0627.tlg033.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De natura muliebri
#     Word token count is 15242
#   Parsing tlg0627.tlg037.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De virginum morbis
#     Word token count is 547
#   Parsing tlg0627.tlg051.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Praeceptiones
#     Word token count is 1651
#   Parsing tlg0627.tlg032.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De affectionibus interioribus
#     Word token count is 19652
#   Parsing tlg0627.tlg008.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De officina medici
#     Word token count is 3075
#   Parsing tlg0627.tlg048.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De natura ossium
#     Word token count is 3951
#   Parsing tlg0627.tlg046.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De alimento
#     Word token count is 1897
#   Parsing tlg0627.tlg030.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De fistulis
#     Word token count is 1925
#   Parsing tlg0627.tlg018.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De arte
#     Word token count is 3262
#   Parsing tlg0627.tlg049.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De medico
#     Word token count is 1820
#   Parsing tlg0627.tlg036.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De muliebribus
#     Word token count is 60670
#   Parsing tlg0627.tlg021.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De flatibus
#     Word token count is 3406
#   Parsing tlg0627.tlg025.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De affectionibus
#     Word token count is 9113
#   Parsing tlg0627.tlg053.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De diebus criticis
#     Word token count is 1604
#   Parsing tlg0627.tlg003.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Prognosticon
#     Word token count is 6291
#   Parsing tlg0627.tlg019.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De natura hominis
#     Word token count is 4572
#   Parsing tlg0627.tlg043.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De carnibus
#     Word token count is 4028
#   Parsing tlg0627.tlg013.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Iusiurandum
#     Word token count is 300
#   Parsing tlg0627.tlg012.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Aphorismi
#     Word token count is 10237
#   Parsing tlg0627.tlg026.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De locis in homine
#     Word token count is 10365
#   Parsing tlg0627.tlg024.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De genitura
#     Word token count is 8452
#   Parsing tlg0627.tlg045.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De corde
#     Word token count is 1252
#   Parsing tlg0627.tlg050.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De habitu decenti
#     Word token count is 1882
#   Parsing tlg0627.tlg040.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De anatomia
#     Word token count is 302
#   Parsing tlg0627.tlg005.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De diaeta acutorum (spurium)
#     Word token count is 6695
#   Parsing tlg0627.tlg009.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De fracturis
#     Word token count is 13712
#   Parsing tlg0627.tlg038.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De superfoetatione
#     Word token count is 4246
#   Parsing tlg0627.tlg002.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De aere, aquis, locis
#     Word token count is 8964
#   Parsing tlg0627.tlg007.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De capitis vulneribus
#     Word token count is 5951
#   Parsing tlg0627.tlg041.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De dentitione
#     Word token count is 546
#   Parsing tlg0627.tlg017.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Coa praesagia
#     Word token count is 17677
#   Parsing tlg0627.tlg014.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Lex
#     Word token count is 429
#   Parsing tlg0627.tlg035.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De octimestri partu
#     Word token count is 906
#   Parsing tlg0627.tlg022.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De liquidorum usu
#     Word token count is 2005
#   Parsing tlg0627.tlg001.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De prisca medicina
#     Word token count is 6693
#   Parsing tlg0627.tlg055.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Epistulae, Decretum, Orationes
#     Word token count is 14394
#   Parsing tlg0627.tlg039.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De exsectione foetus
#     Word token count is 587
#   Parsing tlg0627.tlg029.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De haemorrhoidibus
#     Word token count is 1138
#   Parsing tlg0627.tlg006.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Epidemiarum
#     Word token count is 23499
#   Parsing tlg0627.tlg028.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De ulceribus
#     Word token count is 4318
#   Parsing tlg0627.tlg004.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De diaeta in morbis acutis
#     Word token count is 7351
#   Parsing tlg0627.tlg011.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Vectiarius
#     Word token count is 6795
#   Parsing tlg0627.tlg023.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De morbis i-iii
#     Word token count is 42741
#   Parsing tlg0627.tlg010.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De articulis
#     Word token count is 25985
#   Parsing tlg0627.tlg031.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De diaeta
#     Word token count is 24263
#   Parsing tlg0627.tlg015.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De humoribus
#     Word token count is 3167
#   Parsing tlg0627.tlg027.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De morbo sacro
#     Word token count is 5556
#   Parsing tlg0627.tlg052.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De crisibus
#     Word token count is 2578
#   Parsing tlg0627.tlg020.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De salubri diaeta
#     Word token count is 1709
# Processing works by Galen...
#   Parsing tlg0057.tlg107.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De experientia medica
#     Word token count is 1247
#   Parsing tlg0057.tlg054.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De tumoribus praeter naturam
#     Word token count is 4975
#   Parsing tlg0057.tlg055.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De inaequali intemperie
#     Word token count is 3746
#   Parsing tlg0057.tlg021.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De semine
#     Word token count is 24577
#   Parsing tlg0057.tlg018.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De motu musculorum
#     Word token count is 17719
#   Parsing tlg0057.tlg093.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Adversus Lycum
#     Word token count is 8730
#   Parsing tlg0057.tlg060.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De dignoscendis pulsibus
#     Word token count is 37112
#   Parsing tlg0057.tlg019.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De Victu Attenuante
#     Word token count is 7480
#   Parsing tlg0057.tlg003.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Quod optimus medicus sit quoque philosophus
#     Word token count is 1699
#   Parsing tlg0057.tlg027.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Quod animi mores corporis temperamenta sequantur
#     Word token count is 10014
#   Parsing tlg0057.tlg059.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De differentiis pulsuum
#     Word token count is 50668
#   Parsing tlg0057.tlg096.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De Humero iis Modis Prolapso quos Hippocrates non Vidit
#     Word token count is 11267
#   Parsing tlg0057.tlg009.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De temperamentis
#     Word token count is 34045
#   Parsing tlg0057.tlg050.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De plenitudine
#     Word token count is 13304
#   Parsing tlg0057.tlg073.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Quos quibus catharticis medicamentis et quando purgare oporteat
#     Word token count is 2324
#   Parsing tlg0057.tlg103.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De consuetudinibus
#     Word token count is 4593
#   Parsing tlg0057.tlg062.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De praesagitione ex pulsibus
#     Word token count is 42281
#   Parsing tlg0057.tlg065.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De diebus decretoriis
#     Word token count is 31837
#   Parsing tlg0057.tlg067.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Ad Glauconem de methodo medendi
#     Word token count is 26574
#   Parsing tlg0057.tlg064.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De crisibus
#     Word token count is 40159
#   Parsing tlg0057.tlg066.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De methodo medendi
#     Word token count is 184216
#   Parsing tlg0057.tlg099.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis Prognosticum
#     Word token count is 49155
#   Parsing tlg0057.tlg015.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De instrumento odoratus
#     Word token count is 4952
#   Parsing tlg0057.tlg042.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De causis morborum
#     Word token count is 7095
#   Parsing tlg0057.tlg085.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis De natura hominis
#     Word token count is 28217
#   Parsing tlg0057.tlg011.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De anatomicis administrationibus
#     Word token count is 91646
#   Parsing tlg0057.tlg024.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De optima corporis nostri constitutione
#     Word token count is 2130
#   Parsing tlg0057.tlg057.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De locis affectis
#     Word token count is 81864
#   Parsing tlg0057.tlg072.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De purgantium medicamentorum facultate
#     Word token count is 3496
#   Parsing tlg0057.tlg047.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De totius morbi temporibus
#     Word token count is 4252
#   Parsing tlg0057.tlg013.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De venarum arteriarumque dissectione
#     Word token count is 8621
#   Parsing tlg0057.tlg071.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De hirudinibus, revulsione, cucurbitula, incisione et scarificatione
#     Word token count is 831
#   Parsing tlg0057.tlg048.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De typis
#     Word token count is 1881
#   Parsing tlg0057.tlg002.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De optima doctrina
#     Word token count is 2236
#   Parsing tlg0057.tlg001.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Adhortatio ad artes addiscendas
#     Word token count is 6191
#   Parsing tlg0057.tlg025.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De bono habitu
#     Word token count is 998
#   Parsing tlg0057.tlg087.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis De victu acutorum
#     Word token count is 77155
#   Parsing tlg0057.tlg017.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De usu partium corporis humani I-XI
#     Word token count is 228435
#   Parsing tlg0057.tlg086.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis vel Polybi Opus de Salubri Victus Ratione Privatorum Commentarius
#     Word token count is 8056
#   Parsing tlg0057.tlg083.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De praenotione ad Epigenem
#     Word token count is 12700
#   Parsing tlg0057.tlg063.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Synopsis librorum suorum de pulsibus
#     Word token count is 18316
#   Parsing tlg0057.tlg061.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De causis pulsuum
#     Word token count is 37662
#   Parsing tlg0057.tlg089.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis Epidemiarum I
#     Word token count is 182784
#   Parsing tlg0057.tlg031.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De usu pulsuum
#     Word token count is 5272
#   Parsing tlg0057.tlg006.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De constitutione artis medicae ad Patrophilum
#     Word token count is 14511
#   Parsing tlg0057.tlg046.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De morborum temporibus
#     Word token count is 6259
#   Parsing tlg0057.tlg045.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De differentiis febrium
#     Word token count is 24537
#   Parsing tlg0057.tlg102.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De musculorum dissectione ad tirones
#     Word token count is 16520
#   Parsing tlg0057.tlg028.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De propriorum animi cuiuslibet affectuum dignotione et curatione
#     Word token count is 9928
#   Parsing tlg0057.tlg101.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis De officina medici
#     Word token count is 47755
#   Parsing tlg0057.tlg074.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Pro puero epileptico consilium
#     Word token count is 3731
#   Parsing tlg0057.tlg035.1st1K-grc2_oga020_src.conllu...
#     Work title identified: De venereis
#     Word token count is 481
#   Parsing tlg0057.tlg058.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De pulsibus ad tirones
#     Word token count is 7179
#   Parsing tlg0057.tlg100.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis De fracturis
#     Word token count is 47770
#   Parsing tlg0057.tlg095.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis De articulis
#     Word token count is 59063
#   Parsing tlg0057.tlg070.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De curandi ratione per venae sectionem
#     Word token count is 11633
#   Parsing tlg0057.tlg052.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De comate secundum Hippocratem
#     Word token count is 4077
#   Parsing tlg0057.tlg036.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De sanitate tuenda
#     Word token count is 79707
#   Parsing tlg0057.tlg043.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De symptomatum differentiis
#     Word token count is 7873
#   Parsing tlg0057.tlg039.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De ptisana
#     Word token count is 2661
#   Parsing tlg0057.tlg051.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De tremore, palpitatione, convulsione et rigore
#     Word token count is 10798
#   Parsing tlg0057.tlg068.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De venae sectione adversus Erasistratum
#     Word token count is 7032
#   Parsing tlg0057.tlg022.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De foetuum formatione
#     Word token count is 9051
#   Parsing tlg0057.tlg007.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Ars Medica
#     Word token count is 19759
#   Parsing tlg0057.tlg029.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De animi cuiuslibet peccatorum dignotione et curatione
#     Word token count is 7526
#   Parsing tlg0057.tlg012.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De ossibus ad tirones
#     Word token count is 8178
#   Parsing tlg0057.tlg030.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De atra bile
#     Word token count is 7397
#   Parsing tlg0057.tlg084.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De substantia facultatum naturalium fragmentum
#     Word token count is 1653
#   Parsing tlg0057.tlg020.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De utilitate respirationis
#     Word token count is 7267
#   Parsing tlg0057.tlg056.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De difficultate respirationis
#     Word token count is 37950
#   Parsing tlg0057.tlg075.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De simplicium medicamentorum temperamentis ac facultatibus I-VI
#     Word token count is 80061
#   Parsing tlg0057.tlg053.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De marcore
#     Word token count is 6824
#   Parsing tlg0057.tlg008.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De elementis ex Hippocrate
#     Word token count is 16483
#   Parsing tlg0057.tlg041.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De morborum differentiis
#     Word token count is 7944
#   Parsing tlg0057.tlg069.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De venae sectione adversus Erasistrateos Romae degentes
#     Word token count is 10471
#   Parsing tlg0057.tlg092.1st1K-grc1_oga020_src.conllu...
#     Work title identified: In Hippocratis Aphorismos Commentarii VII
#     Word token count is 111186
#   Parsing tlg0057.tlg081.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Institutio logica
#     Word token count is 10847
#   Parsing tlg0057.tlg094.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Adversus ea quae Juliano in Hippocratis Aphorismos enuntiata sunt
#     Word token count is 8923
#   Parsing tlg0057.tlg049.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Adversus eos qui de typis scripserunt vel de circuitibus
#     Word token count is 6627
#   Parsing tlg0057.tlg077.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De compositione medicamentorum per genera
#     Word token count is 131852
#   Parsing tlg0057.tlg037.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De alimentorum facultatibus
#     Word token count is 51278
#   Parsing tlg0057.tlg044.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De symptomatum causis
#     Word token count is 34543
#   Parsing tlg0057.tlg034.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De parvae pilae exercitio
#     Word token count is 2005
#   Parsing tlg0057.tlg032.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De placitis Hippocratis et Platonis
#     Word token count is 112509
#   Parsing tlg0057.tlg082.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De sophismatis seu captionibus penes dictionem
#     Word token count is 3100
#   Parsing tlg0057.tlg023.1st1K-grc1_oga020_src.conllu...
#     Work title identified: An in arteriis sanguis contineatur
#     Word token count is 5627
#   Parsing tlg0057.tlg033.1st1K-grc1_oga020_src.conllu...
#     Work title identified: Thrasybulus sive utrum medicinae sit an gymnasticae hygieine
#     Word token count is 16579
#   Parsing tlg0057.tlg010.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De naturalibus facultatibus
#     Word token count is 38076
#   Parsing tlg0057.tlg079.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De theriaca ad Pisonem
#     Word token count is 14986
#   Parsing tlg0057.tlg014.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De nervorum dissectione
#     Word token count is 4125
#   Parsing tlg0057.tlg076.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De compositione medicamentorum secundum locos libri X
#     Word token count is 182596
#   Parsing tlg0057.tlg040.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De dignotione ex insomniis
#     Word token count is 582
#   Parsing tlg0057.tlg114.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De causis respirationis
#     Word token count is 810
#   Parsing tlg0057.tlg038.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De rebus boni malique suci
#     Word token count is 12158
#   Parsing tlg0057.tlg078.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De antidotis
#     Word token count is 36844
#   Parsing tlg0057.tlg004.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De sectis ad eos qui introducuntur
#     Word token count is 7676
#   Parsing tlg0057.tlg016.1st1K-grc1_oga020_src.conllu...
#     Work title identified: De uteri dissectione
#     Word token count is 3872
# Data successfully parsed and combined.
#
# Total word token counts by author:
#   Hippocrates: 423569 tokens
#   Galen: 2801392 tokens
#
# Sample of the parsed data:
#           form      lemma upostag    xpostag feats deprel      work_title  \
# 0  ΠΡΟΡΡΗΤΙΚΟS  προετικὸς       n  n--------  None    ExD  Prorrheticon I
# 1           Α.         α.       x  x--------  None   AuxG  Prorrheticon I
# 2            1          1       u  u--------  None   AuxG  Prorrheticon I
# 3          [0]        [0]       -  ---------  None   PRED  Prorrheticon I
# 4            .          .       u  u--------  None   AuxK  Prorrheticon I
#
#   sent_id           sentence_text  \
# 0       1  ΠΡΟΡΡΗΤΙΚΟS Α. 1 [0] .
# 1       1  ΠΡΟΡΡΗΤΙΚΟS Α. 1 [0] .
# 2       1  ΠΡΟΡΡΗΤΙΚΟS Α. 1 [0] .
# 3       1  ΠΡΟΡΡΗΤΙΚΟS Α. 1 [0] .
# 4       1  ΠΡΟΡΡΗΤΙΚΟS Α. 1 [0] .
#
#                                    source_file       author
# 0  tlg0627.tlg016.1st1K-grc1_oga020_src.conllu  Hippocrates
# 1  tlg0627.tlg016.1st1K-grc1_oga020_src.conllu  Hippocrates
# 2  tlg0627.tlg016.1st1K-grc1_oga020_src.conllu  Hippocrates
# 3  tlg0627.tlg016.1st1K-grc1_oga020_src.conllu  Hippocrates
# 4  tlg0627.tlg016.1st1K-grc1_oga020_src.conllu  Hippocrates

# %% [markdown]
# ### Inspect data samples

# %%
# Inspect a sample of Hippocrates's data
print("\n")
galen_sample = combined_df[combined_df["author"] == "Hippocrates"]
print("Sample data for Hippocrates:")
print(galen_sample.tail(10))
print("\n")

# Inspect a sample of Galen's data
galen_sample = combined_df[combined_df["author"] == "Galen"]
print("Sample data for Galen:")
print(galen_sample.tail(10))
# Out:
# Sample data for Hippocrates:
#               form      lemma upostag    xpostag  \
# 423559  ἐπίστασθαι  ἐπίσταμαι       v  v--pne---
# 423560          ἐκ         ἐκ       r  r--------
# 423561         τῆς          ὁ       l  l-s---fg-
# 423562      ἑωυτοῦ     ἑαυτοῦ       p  p-s---mg-
# 423563      γνώμης      γνώμη       n  n-s---fg-
# 423564          ἐν         ἐν       r  r--------
# 423565        τῇσι          ὁ       l  l-p---fd-
# 423566   νούσοισιν      νόσος       n  n-p---fd-
# 423567  ὠφελέεσθαι     ὠφελέω       v  v--pne---
# 423568           .          .       u  u--------
#
#                                               feats deprel         work_title  \
# 423559    {'Mood': 'n', 'Tense': 'p', 'Voice': 'e'}    SBJ  De salubri diaeta
# 423560                                         None   AuxP  De salubri diaeta
# 423561  {'Case': 'g', 'Gender': 'f', 'Number': 's'}    ATR  De salubri diaeta
# 423562  {'Case': 'g', 'Gender': 'm', 'Number': 's'}    ATR  De salubri diaeta
# 423563  {'Case': 'g', 'Gender': 'f', 'Number': 's'}    ADV  De salubri diaeta
# 423564                                         None   AuxP  De salubri diaeta
# 423565  {'Case': 'd', 'Gender': 'f', 'Number': 'p'}    ATR  De salubri diaeta
# 423566  {'Case': 'd', 'Gender': 'f', 'Number': 'p'}    ADV  De salubri diaeta
# 423567    {'Mood': 'n', 'Tense': 'p', 'Voice': 'e'}    OBJ  De salubri diaeta
# 423568                                         None   AuxK  De salubri diaeta
#
#        sent_id                                      sentence_text  \
# 423559      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423560      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423561      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423562      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423563      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423564      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423565      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423566      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423567      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
# 423568      86  Ἄνδρα δὲ χρὴ , ὅς ἐστι συνετὸς , λογισάμενον ὅ...
#
#                                         source_file       author
# 423559  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423560  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423561  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423562  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423563  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423564  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423565  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423566  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423567  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
# 423568  tlg0627.tlg020.1st1K-grc1_oga020_src.conllu  Hippocrates
#
#
# Sample data for Galen:
#              form    lemma upostag    xpostag  \
# 3224951        ἐν       ἐν       r  r--------
# 3224952     ἑτέρῳ   ἕτερος       a  a-s---md-
# 3224953      λόγῳ    λόγος       n  n-s---md-
# 3224954        τῷ        ὁ       l  l-s---md-
# 3224955      περὶ     περί       r  r--------
# 3224956       τῆς        ὁ       l  l-s---fg-
# 3224957       τοῦ        ὁ       l  l-s---ng-
# 3224958   ἐμβρύου  ἔμβρυος       n  n-s---mg-
# 3224959  ἀνατομῆς  ἀνατομή       n  n-s---fg-
# 3224960         .        .       u  u--------
#
#                                                feats deprel  \
# 3224951                                         None   AuxP
# 3224952  {'Case': 'd', 'Gender': 'm', 'Number': 's'}    ATR
# 3224953  {'Case': 'd', 'Gender': 'm', 'Number': 's'}    ADV
# 3224954  {'Case': 'd', 'Gender': 'm', 'Number': 's'}    ATR
# 3224955                                         None   AuxP
# 3224956  {'Case': 'g', 'Gender': 'f', 'Number': 's'}    ATR
# 3224957  {'Case': 'g', 'Gender': 'n', 'Number': 's'}    ATR
# 3224958  {'Case': 'g', 'Gender': 'n', 'Number': 's'}    ATR
# 3224959  {'Case': 'g', 'Gender': 'f', 'Number': 's'}    ATR
# 3224960                                         None   AuxK
#
#                    work_title sent_id  \
# 3224951  De uteri dissectione     161
# 3224952  De uteri dissectione     161
# 3224953  De uteri dissectione     161
# 3224954  De uteri dissectione     161
# 3224955  De uteri dissectione     161
# 3224956  De uteri dissectione     161
# 3224957  De uteri dissectione     161
# 3224958  De uteri dissectione     161
# 3224959  De uteri dissectione     161
# 3224960  De uteri dissectione     161
#
#                                              sentence_text  \
# 3224951  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224952  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224953  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224954  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224955  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224956  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224957  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224958  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224959  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
# 3224960  καὶ τὰ περὶ τῶν ἀγγείων τῶν εἰς τὸ ἔμβρυον διὰ...
#
#                                          source_file author
# 3224951  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224952  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224953  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224954  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224955  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224956  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224957  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224958  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224959  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen
# 3224960  tlg0057.tlg016.1st1K-grc1_oga020_src.conllu  Galen

# %% [markdown]
# ## Step 5: Define queries for lemma, morphological features, and syntactical relation frequencies

# %%
# Lemma Frequency Query
def query_lemma_frequency(lemma):

    results = {}
    for author in combined_df["author"].unique():
        author_df = combined_df[combined_df["author"] == author]
        total_tokens = len(author_df)
        lemma_count = len(author_df[author_df["lemma"] == lemma])
        frequency = (lemma_count / total_tokens) * 100 if total_tokens > 0 else 0
        results[author] = frequency
    return results

# Morphological Feature Frequency Query
def query_morph_feature_frequency(feature_key, feature_value):

    results = {}

    for author in combined_df["author"].unique():
        author_df = combined_df[combined_df["author"] == author]
        total_tokens = len(author_df)

        # Count occurrences of the feature key-value pair in the feats column
        feature_count = author_df["feats"].apply(
            lambda x: isinstance(x, dict) and x.get(feature_key) == feature_value
        ).sum()

        # Calculate frequency as a percentage
        frequency = (feature_count / total_tokens) * 100 if total_tokens > 0 else 0
        results[author] = frequency

    return results

# Syntactical Feature Frequency Query
def query_syntactical_feature_frequency(deprel):

    results = {}
    for author in combined_df["author"].unique():
        author_df = combined_df[combined_df["author"] == author]
        total_tokens = len(author_df)
        deprel_count = len(author_df[author_df["deprel"] == deprel])
        frequency = (deprel_count / total_tokens) * 100 if total_tokens > 0 else 0
        results[author] = frequency
    return results

# %% [markdown]
# ### Sample Lemma Query

# %%
# Sample query: Which medical author is more concerned with embryoes?
lemma_to_query = "ἔμβρυος"
lemma_frequencies = query_lemma_frequency(lemma_to_query)
print(f"Lemma frequencies for '{lemma_to_query}':")
for author, frequency in lemma_frequencies.items():
    print(f"  {author}: {frequency:.3f}%")
# Out:
# Lemma frequencies for 'ἔμβρυος':
#   Hippocrates: 0.007%
#   Galen: 0.001%

# %% [markdown]
# ### Sample Morphological Feature Query

# %%
# Example: Which medical author is more apt to use feminine words ('Gender': 'f')
feature_key = "Gender"
feature_value = "f"

morph_frequencies = query_morph_feature_frequency(feature_key, feature_value)
print(f"\nMorphological feature frequencies for '{feature_key}={feature_value}':")
for author, frequency in morph_frequencies.items():
    print(f"  {author}: {frequency:.2f}%")
# Out:
# Morphological feature frequencies for 'Gender=f':
#   Hippocrates: 12.95%
#   Galen: 15.63%

# %% [markdown]
# ### Sample Syntactical Relation Query

# %%
# Sample query: Which medical author uses more attributive modifiers?
syntactic_feature_to_query = "ATR"
syntactic_frequencies = query_syntactical_feature_frequency(syntactic_feature_to_query)
print(f"\nSyntactical feature frequencies for '{syntactic_feature_to_query}':")
for author, frequency in syntactic_frequencies.items():
    print(f"  {author}: {frequency:.3f}%")
# Out:
# Syntactical feature frequencies for 'ATR':
#   Hippocrates: 18.015%
#   Galen: 23.530%

# %% [markdown]
# ## Define Sentence Retrieval and Translation Query Functions

# %%
# install googletranslate if necessary, then load library
# !pip install deep-translator

from deep_translator import GoogleTranslator

def find_lemma_sentences(lemma, author):
    author_df = combined_df[combined_df["author"] == author]
    lemma_indices = author_df[author_df["lemma"] == lemma].index
    sentences = []
    for idx in lemma_indices:
        sent_row = author_df.iloc[idx]
        sentence_text = sent_row.get("sentence_text", "")
        if not sentence_text:
            sentence_text = combined_df.loc[author_df.loc[idx, "sent_id"], "# text"]
        sentences.append(sentence_text)  # Append only the sentence text
    return sentences

def translate_text_with_length_check(text):
    max_length = 5000
    if len(text) > max_length:
        return "Translation error: Input text exceeds the length limit (5000 characters)."
    try:
        return GoogleTranslator(source='auto', target='en').translate(text)
    except Exception as e:
        return f"Translation error: {e}"

def display_sentences_with_translation(sentences):
    for i, sentence in enumerate(sentences):
        print(f"\nGreek Sentence {i + 1}/{len(sentences)}:")
        print(sentence)
        plain_translation = translate_text_with_length_check(sentence)
        print("\nEnglish Translation:")
        print(plain_translation)
        if i < len(sentences) - 1:
            next_step = input("\nTranslate next occurrence? (Y/N): ").strip().lower()
            if next_step != "y":
                print("Exiting...")
                break
# Out:
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)

# %% [markdown]
# ### Set and Run Sentence Retrieval and Translation query

# %%
# Example Usage
lemma_to_query = "ἔμβρυος"  # Replace with the lemma of interest
author_to_query = "Hippocrates"  # Replace with the author of interest

sentences = find_lemma_sentences(lemma_to_query, author_to_query)
if sentences:
    print(f"Found {len(sentences)} sentences for lemma '{lemma_to_query}' by {author_to_query}.")
    display_sentences_with_translation(sentences)
else:
    print(f"No sentences found for lemma '{lemma_to_query}' by {author_to_query}.")
# Out:
# Found 29 sentences for lemma 'ἔμβρυος' by Hippocrates.
#
# Greek Sentence 1/29:
# εἰ δέ τι κείνων ἐπιφαίνοιτο , τῷ τε ἐμβρύῳ ὄλεθρον σημαίνει καὶ τῇ ἐχούσῃ κίνδυνον , ἢν μὴ μετὰ τοῦ ἐμβρύου τὴν ἀπόφευξιν καὶ τοῦ ὑστέρου τὴν ἀπόλυσιν ἡ δυσεντερίη παύσηται αὐθημερὸν [0] ;
#
# English Translation:
# If what is seen of that, does it mean destruction for the fetus and pose a danger to her, or does not the dysentery cease immediately after the expulsion of the fetus and the subsequent expulsion of the uterus? [0]
#
# Translate next occurrence? (Y/N): y
#
# Greek Sentence 2/29:
# εἰ δέ τι κείνων ἐπιφαίνοιτο , τῷ τε ἐμβρύῳ ὄλεθρον σημαίνει καὶ τῇ ἐχούσῃ κίνδυνον , ἢν μὴ μετὰ τοῦ ἐμβρύου τὴν ἀπόφευξιν καὶ τοῦ ὑστέρου τὴν ἀπόλυσιν ἡ δυσεντερίη παύσηται αὐθημερὸν [0] ;
#
# English Translation:
# If what is seen of that, does it mean destruction for the fetus and pose a danger to her, or does not the dysentery cease immediately after the expulsion of the fetus and the subsequent expulsion of the uterus? [0]
#
# Translate next occurrence? (Y/N): Y
#
# Greek Sentence 3/29:
# καὶ ἀπὸ τῆς μήτρης παραγίνεται ἐπὶ τοὺς μαζοὺς ἐς τὴν μετὰ τὸν τόκον τῷ παιδίῳ τροφὴν , ἥν τινα ἀποπιέζει καὶ ὑπερβάλλει τὸ ἐπίπλοον ἐς τὰ ἄνω , στενοχωρούμενον ὑπὸ τοῦ ἐμβρύου .
#
# English Translation:
# And from the womb, the nourishment for the child after birth is produced in masses, which somewhat suppresses and overwhelms the upper part, distressed by the fetus.
